# %%
import os
# List of sequential point cloud files (Replace with actual filenames)
point_cloud_files = os.listdir("output_pcds")
point_cloud_files = [f"output_pcds/{f}" for f in point_cloud_files][:200:2]
