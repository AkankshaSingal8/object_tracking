# %%
import os
from typing import Iterable, Dict
import tensorflow as tf
import kerasncp as kncp
from kerasncp.tf import LTCCell, WiredCfcCell
from tensorflow import keras
import numpy as np
from matplotlib.image import imread
from tqdm import tqdm
from PIL import Image
import pandas as pd
import time
import matplotlib.pyplot as plt
import cv2 as cv
# Out:
# 2024-08-13 07:57:20.921544: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0

# %%
result_directory = "SINGLE_STEP_FINE_TUNED_NEW_DATA"
train_root = "../fly_to_target_dataset/original_dataset"
test_root = "../fly_to_target_dataset/test_data"

# %%
for directory in range(len(os.listdir(test_root))):
    error = pd.read_csv(f"{result_directory}/errors_test_data{directory + 1}.csv").to_numpy()

    fig, axs = plt.subplots(4, 1, figsize=(10, 8), sharex=True)

    for i in range(4):
        axs[i].plot(error[:, i])
        axs[i].set_title(f'Error in Dimension {i+1}')
        axs[i].set_ylabel('Error')
        axs[i].grid(True)

    axs[3].set_xlabel('Sequence Length')

    plt.tight_layout()
    plt.savefig(f"{result_directory}/errors_test_graph{directory + 1}.png")

# %%
for directory in range(len(os.listdir(train_root))):
    error = pd.read_csv(f"{result_directory}/errors_train_data{directory + 1}.csv").to_numpy()

    fig, axs = plt.subplots(4, 1, figsize=(10, 8), sharex=True)

    for i in range(4):
        axs[i].plot(error[:, i])
        axs[i].set_title(f'Error in Dimension {i+1}')
        axs[i].set_ylabel('Error')
        axs[i].grid(True)

    axs[3].set_xlabel('Sequence Length')

    plt.tight_layout()
    plt.savefig(f"{result_directory}/errors_train_graph{directory + 1}.png")
# Out:
# /tmp/ipykernel_571928/708110131.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axs = plt.subplots(4, 1, figsize=(10, 8), sharex=True)
